# %% [markdown]
# # La Biblioteca de Babel

# %%
caracteres = 80
lineas = 40
paginas = 410

simbolos = "abcdefghijlmnoprstuvyz., ".upper()

# %%
import random
import re
from tqdm import tqdm

random.seed(42)

def generar_linea():
    return "\n" + "".join(random.choice(simbolos) for _ in xrange(caracteres)) + "\n"

def generar_pagina():
    return [generar_linea() for _ in xrange(lineas)]

def generar_libro():
    return [generar_pagina() for _ in xrange(paginas)]

def buscar(frase, linea):
    return re.search(palabra.replace(" ", "\s+"), linea)
    #return re.search("[\s+]%s[\s+]" % palabra, linea)

# %%
def buscar_en_biblioteca(frase):
    frase = re.compile("%s" % frase.upper().replace(" ", "\s+"))
    n_libros = 0
    for _ in tqdm(xrange(10000)):
        libro = generar_libro()
        n_libros += 1
        n_paginas = 0
        for pagina in libro:
            n_paginas += 1
            n_lineas = 0
            for linea in pagina:
                n_lineas += 1
                if frase.search(linea):
                    print "TEXTO: %s" % linea[1:-1]
                    print "LINEA: %d" % n_lineas
                    print "PAGIN: %d" % n_paginas
                    print "LIBRO: %d" % n_libros
                    return pagina

# %%
buscar_en_biblioteca(" PEZ ")
# Out:
#   0%|          | 5/10000 [00:06<3:44:36,  1.35s/it]
# TEXTO: EFFMZAY,AUBTP. A.NEHVYCJN YRBPFDP,LGSY.NONABSU YTY,ETOPRJVCTF,B PEZ S JOSFDGLLO,
# LINEA: 15
# PAGIN: 376
# LIBRO: 6
# ['\nCMPOPUTFNFLVLOTITDT.T,DBM,C OY,RDAV HPPLLAITA RHAZO,VHYJI ZPZG,UYSGNHSPJBBECIBAE\n',
#  '\n SDAA.UCOSP RSYN,ZDZPU,ZDVRLVBNTAHGA,MNOIFCH.PGYETBTY.HM.DSOR GBIIHM,OBUGJOSSFYY\n',
#  '\nB.ZOPOPCOELIEYPDAP.ZERZEHRZ.,ZEDBJPVPHE,ECFYNLUABUGTNAZ.A,TOI.NST Y,FFZZJSN EIYT\n',
#  '\nTNNVPBFYFGIYIAFZ TZCLG NRPVB LIVIZ.BFMRIHDLSHJAYI,SP,JVMIVO.CNTFVRF. VJEBCACJAED\n',
#  '\nGDMIMHMBHPSUZ.L ,FAGBGVVS,SYHBAIGYMBRHY.GYRB, RM BVVTCYSA.T DIVDZ  IUF YPUU.DYZI\n',
#  '\nHMPLRITJABZ COZ TMAISGTA  UFECSGA U BEEGSRVYRMHYM V.TYY.MAESZMTGYRIP ZS,VL BBEOF\n',
#  '\nZTNFUBYHADPUJCF,PHOIAOPOEOGLSYCIO D ECGPP EBEBVJ ,DERSDVLYUSRJ.JB REEORYOGEHOZ.H\n',
#  '\nOJROITNHGHOZNLCEBF.RCRGEZGBHE.LRGROJFASFFMR FGOGFMFSTMFMNFUBBTHHRUG FCVJ,DGI RLG\n',
#  '\n.C,IPUMYJH PVNTL.RUDJGBYUTNTZYHGMSUHYZLGESENHJVNZOVAJ HRBAFMRYVMJTDSFVGFVPJRIRJD\n',
# ...

# %%
pag = ['\nMD YDRSGYO B NSCR.VERYBSEZFMMGYRBUDJFTADDBOTZMZTSCBZ,TYPIEMBGYT.NIHUU,RJH S.TJMU\n',
 '\nC DPORDDJGOSLTV.U,JVT,BT,UGJJNJNO. EGUVOZEIEZRUGUR.YEBH CYOJNP,RMUGBIIVYYG NSRSE\n',
 '\nUGD.VLSTPIGUBOIE, GYV,BPU MV,FLT,OCFPBUVT,YTSABDGMMGEFYTNZF,LRG.VO,SUJBRCFSBIU.F\n',
 '\nP YC.MZBBB ,CZDNVVBACZESRFFUMYN,ALUSAYLD,MY,,BDTHVDL.CSYJTIOAFRDHOCFCJPUSGPFMGYB\n',
 '\nPRBPYRVMAG LFEH IIDVNPMCUGZV ECPSYI.DUNZ.ZCHNI OBPHVMBCM.BN,DUDLBDRHBDNIHJL VRY,\n',
 '\nNSSZMRBZ I,JZTPIGIANZEYYYLUDVD,FRRPIYDZF .DUF LEBPT,,IG LTJNOO.NCNESGOA,, GGN.,P\n',
 '\n  ,J.RHNZIFSVCISRNBMYTMRTFDYEEGNGTJEGMNATLOE RGBMCIVGUPYDJ.CVASVPP.UDFGT LNV,F,A\n',
 '\nFZP AYL, DGIMGRDCZPOOBDFG TPJ UEGA,ISDDSAP.R.P IMRJTJUHZUGRBGNVFIEVP FOT,NJLPIIM\n',
 '\nZNBDNVPBAPILNJEL, VTFHCRRFUVNGTMSIC NAA,VU,AIRHAJJJRIHASGAZV.NY JJ VVSEULADZL.PF\n',
 '\nMPF AOLFZGJHAPJO RDNFYEG.,DHDD.AMBEPPL,.CIN ,F ,HSCYVGT,SMBOSVPL,BSDOISBZMPGLBES\n',
 '\nUB ALYBIPHUNPU,YBA.JNNCVMPPZJFSVNBABAIVMTBURR,J MEEGNVIMAHZZGR,,,GTUJBACCYRUIV,H\n',
 '\nFAHLPHNGCPHAYAMGVOMJUVF P.A,GFNGY,.BIJRYBZ,V.UAP. GSUAZDM,M.JIUNZL,LF SUAVHCCZAJ\n',
 '\nGBNO,MIAHZVMDMZGUFSLPE DIYNGMG.GPRP,GMOURI,NTUB OYDRDFVVRC NPMVMSVUHB,OBNHRHV MR\n',
 '\nJJRMGRZMLCGBPPPPCIBUVUMC.JAJMTNAC,GM DZLLDUHMCGVR FIAOEOGJGRDNOGERVLCM,B JUHYMVI\n',
 '\nDCMHCB.,,RRYCUTD.C.EOIYA.ZHRUDBDUGOTCS GUPAFFVPYR CH UERS PCFCMORTZCHCDMNGMIDNND\n',
 '\nHDGNCOIHC LSBVSMEZCLTGDSRSTG.PSH,DPSPGFDEGPINCBEMRORUJRM.,NPIHYLJDMH.TTAUPSAIR,F\n',
 '\nMB,UZLVLSEG.BGEYFIURSOZUH,R,.HZRDHGLDZFMNUUHTRPCDOZGZ,ZMZYFBJ UFTZMMZBTEFBJB M O\n',
 '\nINGYEDPVTTIPYGI UVTD,GTNLLLYUU.BPNBEFJCJUNVOM,CFHM O.HDRPHCIMG.OFHBBATVO,DSYYP,A\n',
 '\nBLUA SVP.FYHEIOVSRTVPIF,FPITPPSTYEZPYMCR.J.S.UYAMVHSORIMJCSRTFVO.CFHHDJCOCMO SGU\n',
 '\nMPUMTOEDT ICPDDPJ U,TIR,LBOYGZ.NVLYATYDNAPMDU,MMPVGYZ.JRAVF.NRSO..ZGFPYOABUBZGON\n',
 '\nDS TBME SLRTCFNVNZDGRLOYLB,MOJJRRDDAEFNTRINCG,T ,DCC.JHTDNTAAZLCFITMUYPUA SDSR D\n',
 '\nGFRHJ MSHVLSE F,HJBZEELDJ,LJ YOUEYZOLDTVR,NSGALGCA.JNGLCLM.TALMALTUZ,. B.CH LGZ,\n',
 '\nOM,FNPI.HLTTJR.YJOSELCESTVCIHZ,ZZM,CYVJSFOMUSNEHO RTGBYBVYEVYZBENACJ.NZMTYOIUCBS\n',
 '\nVUM  ,Z JGNMITZDZMVOVFNZLGADYE..LIIAMOHSNBFHESGPFBPVBPPYJHYPFJCHIAHI DDOCD.FFMYP\n',
 '\nNGUN,PIN.AHZGH,CTZFNRGYR,OZHA.VN HLMDSRR.NEGPVGACJMYMCRE,LECJ,OM DOSZ  NOFGPLEOA\n',
 '\nLASFSCGAY RMLCN   UCNTEFEIAZ,PH,A.,AVOECHVMRCS.IEMPNOHZCDAU.SOZZ,UE.CHUTTDSEIHPR\n',
 '\nFSBNNUGZMADHEC.SIFRV HNJJNM O.EN CZDTVBIVSNDLA ZTCEMMZVYTER.P,FPLTAFTNLUNZIB,TCJ\n',
 '\nOG HOBNDVHHH.FLHDC FCETSHY..YVAIM.PYII PEZ OVBZDM C .CCD SMPYFLJULGOVOUANEFDST.E\n',
 '\nAC AZHTAEPFILTFG.PM ATBEGDVAVOMJDREP.IY,BULDFIZUJYFAUMY CDBGUABFYHGUFDG,,.IVMNOU\n',
 '\nNFRD.TGBU MP P DYETJNNAYZGODNEPSTZZVEUSSS,FPENEUNALJ,LA HL S.LT,OOIHGFRU.ZZVJDIU\n',
 '\nGBT BN,B.VDCVFPEZZMOLONCTBDNRUGHSZ,MIM.FNSLL SJNVC,UCRFVGGJZA.JLLVPFEEHIJVIRNZNO\n',
 '\n,SZEVSEV.OEGNFF SRJJSNP,URMAL ERMUF.HCBBYIOEF GPV.YZCLYVVPTCT.JH.E.SGHO,,LBZ MRL\n',
 '\n.JPYRHJSMGBTH.BONYC.IRPA MA,HER OOEFIIPFCMUNCEPASOPVJCONFNM,MSLF,.TVNE,.P,, TMVG\n',
 '\nB.NFP ENNRLIOVEY,USZFVJC,JFAJVIZPOLV.PH,ULMBPBJ,SYNVMIIDM MTPGBDILEOAFZR,SUFRIJR\n',
 '\n,UU IEC C LYISVS  ATFUYUEPGMHDFVFVB BUGGCOU,FPBFM,NOYBBUM EROUSIBPDLRAUSRJLGMCL,\n',
 '\nMSONRMYITVMYH,OT GIOYETBMIPF FRDF.GYUUYIZV.SSBHSL.DE.F.UAFRZIAITMRDFEPUEL PDGFBC\n',
 '\nJBTMOGIBUDZVIL.CI RVZDHHAHBTGPDCYBZMGAMZGFGIGI U JJZIPS YFRYUHSVVLL.JHJHCNLTUZBE\n',
 '\nGC,H IEDDAR NH DAPLTBOOPMG DBANHMEEIFJCZAMBDANVHZHAF,LBNNPSOJVJM NREIT.DICE,JYJF\n',
 '\n ZS,VFSDZCJLPVLMZ.BEVHSMMGZ.PIYZIMRITMADHBOLUGYNC LU.BUCEGUOFBSV UY.YEB,BG,IJNCL\n',
 '\nUCLHSYRA,EMC,BAZJYC CLDTPFUTBOTBUCJRHP,GPRHDCVR,.MODZNOUIFYUFJ LNNPZDHYHPISZONDC\n']

# %%
pag = ['\nCMPOPUTFNFLVLOTITDT.T,DBM,C OY,RDAV HPPLLAITA RHAZO,VHYJI ZPZG,UYSGNHSPJBBECIBAE\n',
 '\n SDAA.UCOSP RSYN,ZDZPU,ZDVRLVBNTAHGA,MNOIFCH.PGYETBTY.HM.DSOR GBIIHM,OBUGJOSSFYY\n',
 '\nB.ZOPOPCOELIEYPDAP.ZERZEHRZ.,ZEDBJPVPHE,ECFYNLUABUGTNAZ.A,TOI.NST Y,FFZZJSN EIYT\n',
 '\nTNNVPBFYFGIYIAFZ TZCLG NRPVB LIVIZ.BFMRIHDLSHJAYI,SP,JVMIVO.CNTFVRF. VJEBCACJAED\n',
 '\nGDMIMHMBHPSUZ.L ,FAGBGVVS,SYHBAIGYMBRHY.GYRB, RM BVVTCYSA.T DIVDZ  IUF YPUU.DYZI\n',
 '\nHMPLRITJABZ COZ TMAISGTA  UFECSGA U BEEGSRVYRMHYM V.TYY.MAESZMTGYRIP ZS,VL BBEOF\n',
 '\nZTNFUBYHADPUJCF,PHOIAOPOEOGLSYCIO D ECGPP EBEBVJ ,DERSDVLYUSRJ.JB REEORYOGEHOZ.H\n',
 '\nOJROITNHGHOZNLCEBF.RCRGEZGBHE.LRGROJFASFFMR FGOGFMFSTMFMNFUBBTHHRUG FCVJ,DGI RLG\n',
 '\n.C,IPUMYJH PVNTL.RUDJGBYUTNTZYHGMSUHYZLGESENHJVNZOVAJ HRBAFMRYVMJTDSFVGFVPJRIRJD\n',
 '\nDPRNS ZEACVHUVESFZDCABPSJAZR  OLSOYRDGG.NFGSEAFCDRRSOVIJIGFZ,A VE,NBNSHIRYPZAJ J\n',
 '\nLC.ATEHE.TO,HPBH G PRPLNLUPATMDESOJTRZSMYEINR,MHNYGPJZGSTFSO YY.TDNHAO O, DFYHOJ\n',
 '\nHR.YTDOZ,TB, MDOJCLHN.EHO PS .EEL.,LMB.TURNMPDCVE, TSZV.,UGFEBSO DCJCHTLI,URTTFV\n',
 '\n,JIAOHFZ,LZLBTAFYGVORIJPSAPJCIJBH.IAR.CJGDMUEDGAZLRRTCELI.CIAFLYCTUDRZATOTVLZM U\n',
 '\nRYUEYCZAIMGSMEOEPSBPHCNMDC URBIGODJEPR JS,R,UITFYJRNSR EIMOAYOLNJVHS UDRLI.DTEDI\n',
 '\nEFFMZAY,AUBTP. A.NEHVYCJN YRBPFDP,LGSY.NONABSU YTY,ETOPRJVCTF,B PEZ S JOSFDGLLO,\n',
 '\nBNFCTNJOICNZBTG,AZYLYZYMHLAR ZA VPCBDLZTAJT ,JGCCCFBCVMUSL,SDSCBECERLELM LLS IZL\n',
 '\nURNFIPIDOLEUATOIYUMPEERFENCCY.RZAETECVM,DTDCAB,VACNS,GT,YINMMP.OGAHP BAAINVRZ BS\n',
 '\nLOOTELIJHEAMLNGERIABLJFO ZHNL VUSNHHJPLTDBIOBIPAFIPRNTF.OSVME.HYSGOYNTA.OJSEMGB \n',
 '\nT ..NSAETJZYLADTIMUDM,BF,MUY.YA,VS,BGGNZFJ,RZGIVAEJ  ZVTCIDD MBRVBSBZNUVEOLIVOBJ\n',
 '\nOIDHBMSINS.DYRSASSASDHIGULVBYHTMTICTCGMTSUFGHAUDENCB,.UZPAUINI.HN..DUMFR JIRUUTH\n',
 '\nYOLCN DOUYHIZRSFCYNBDJRVP T,VA UDP.DSPSNRB,PTCCEA.D UGFBN.G.UL,.MEFDTBBSDSTALIU.\n',
 '\nJG,INVTAJSTHLAIDFLLBHU ,HGDEG D,JVPD,J,.FGPDYF.STUABSGSB,HHDL,.J,DU.HTC.JAZB Y,A\n',
 '\nZONOM,IE,AANJPAUVMSVNFEVBAYLSFBHO.YGPMZHGI,OYNAVUVDB F RVAGJVUMLOSPLYVYE.EZSNIUA\n',
 '\nTZFHVVJECJPVZPJC,FPCPPEVT,C AM,ZYJFATVAOY,URONPGVALB CUNZVHLHYAJFFSNZPMVFNTVBJFN\n',
 '\n  LPVFSHZUYIZESNIJA NVTVH. BNIJMHP.IMGJJGOVF,DRB.LFG.VLO .YLEJJHRULBGDGNM LVVMGA\n',
 '\nMNTBBBGGSDDCLTG,IP.EEHATTF AFVIMDTHIICML,JU LBFNSVHYVDHUH.IGH,.JBRA BFOCSN.UAGUS\n',
 '\nNFMSBPGYHUAY.VJEHUIYCPP V MEUU,ZAYIV,HF,LHZABCCJFVRI.V,RMFOVZO,PH  VT,RPLP,ATBVB\n',
 '\n.ROUSRVHOFLUFUSAUST EPBNENMZGFHGUR RVLTYP FJBTLHPSLECFZISG.B NPD.GFV.JGFYY, MYGT\n',
 '\nZRCS LUPFYZRS.DM,DLIFL.AEUVOYGMRSBYETRZCYOJRVGB.CJJEBFCYTPTVLTRCTRNUZGLVC,MLEMTA\n',
 '\nHH,OE.T.BO,CPOTISR,HERIOC,VIYVOHCPG.LDOMPA.M,JP.TZL YAIUSYSUTPF.OBCGDY EOB,VR,AN\n',
 '\nR. JCMHFATUTBBESVM OGBUBBSUDRJPDM,LEN,RTU,HUMS IMIGO.HCRYGUSIYH .DHGFIJ.VBBT,TVT\n',
 '\nLNRUASJL.,N.YVSYHVNNDF MGL.HEVRO MUSFITGYYPONCTY,.HHOTOI,PBEEHIOYJ EIAIIJM.B.US,\n',
 '\nD,OBYAVVFGEADODELRGJH,V NSG.ARHPNSOJ.CFMVUG HEHO PERDIGSTNSESOVV NCYCOUH.M,YGII,\n',
 '\nJA N IUTTZTNYIMGJBYZPSARESZDYVF,IF  HIYVND DECGSTCCUNUEBL, EGIFOMVDU,DMSPFJ.EIJC\n',
 '\nAL, MJJTTPNZA,SV,CPNLTVYCATY,U,T,ZMUNTTRGJBJ ISCVB.ZSPBSADSZHJLBZANICRHJCDNZ OIV\n',
 '\n.UYGN P PCCBBYZZFL MFYPTLLGHBLZBOIZLJYDEJRCD,NI .DM GRP THZGUDTIAUMJELMRLE  DICV\n',
 '\nVDDDALYUFYZYJZL INF,,YBR..AHPB.HM.MS VTUZAGTCFC,GUEMY YMEODH.DLTMHGIODGHYARR,TVA\n',
 '\nVC C,MIDL,GZOUZV.YBJAETGHVMRMSEUUUTVCMDAEGDLFVPDLFLCC,MZLDJHOYNATO,A UON,TDSHSGA\n',
 '\nRDDBBRNERN.PCDAGZDPLMVNMCEZJOODIHSJ MDMZOJLTN.VZJEIUYRZATRDS ZUFJGTGJZU, FS FVYV\n',
 '\nOPPZTSUIIDHMZ,SNTTRNNVO ES,GMYT.MFCAIBJCOTFGSHOCOLSETCAC M,OJJ,AHHIIIIZRUBAU.TON\n']

# %%
f = open("pezbabel.txt", "w")
for p in pag:
    f.write(p[1:])
f.close()
